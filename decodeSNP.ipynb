# %%
import json
import numpy as np

js = json.load(file('SNP_encoding.json'))
#print js.keys()
#print js.values()

# revert key-value to value-key
_js = {value:key for key, value in js.items()}
#print _js.keys()

keys = [1791, 8379,   79, 8588, 1540,  961, 3753, 3587, 4525, 5936, 7961, 8138, 1234, 6377, 1923,
        3572, 3306, 3340, 4886, 5224, 6970, 9277, 1226, 3816, 3397, 5720, 7381, 6784, 9163, 6097,
        1381, 7414, 3926, 2982,  592, 5368, 8355, 1974, 5904, 2091, 4254, 6759, 7622, 8796, 3384,
        7302, 7672, 4049, 8995, 5157, 7935, 5273, 7365, 3077, 5906]
values = []
for i in range(len(keys)):
    values.append(_js[keys[i]])
#print values

dic = {u'216': [6759], u'150': [4525], u'199': [6097], u'265': [8379, 8355], u'217': [6784], u'191': [5904, 5906], u'192': [5936], u'115': [3397, 3384], u'114': [3340], u'62': [1791], u'274': [8588], u'113': [3306], u'67': [1923], u'234': [7365], u'235': [7381], u'236': [7414], u'253': [7935], u'172': [5224], u'254': [7961], u'22': [592], u'49': [1381], u'69': [1974], u'173': [5273], u'175': [5368], u'43': [1234, 1226], u'3': [79], u'232': [7302], u'185': [5720], u'281': [8796], u'286': [8995], u'205': [6377], u'143': [4254], u'121': [3587, 3572], u'260': [8138], u'241': [7622], u'125': [3753], u'126': [3816], u'242': [7672], u'128': [3926], u'103': [2982], u'160': [4886], u'222': [6970], u'132': [4049], u'55': [1540], u'35': [961], u'74': [2091], u'106': [3077], u'168': [5157], u'294': [9277], u'293': [9163]}
dic = sorted(dic.iteritems(), key=lambda d:d[0])
print dic
# Out:
# [(u'103', [2982]), (u'106', [3077]), (u'113', [3306]), (u'114', [3340]), (u'115', [3397, 3384]), (u'121', [3587, 3572]), (u'125', [3753]), (u'126', [3816]), (u'128', [3926]), (u'132', [4049]), (u'143', [4254]), (u'150', [4525]), (u'160', [4886]), (u'168', [5157]), (u'172', [5224]), (u'173', [5273]), (u'175', [5368]), (u'185', [5720]), (u'191', [5904, 5906]), (u'192', [5936]), (u'199', [6097]), (u'205', [6377]), (u'216', [6759]), (u'217', [6784]), (u'22', [592]), (u'222', [6970]), (u'232', [7302]), (u'234', [7365]), (u'235', [7381]), (u'236', [7414]), (u'241', [7622]), (u'242', [7672]), (u'253', [7935]), (u'254', [7961]), (u'260', [8138]), (u'265', [8379, 8355]), (u'274', [8588]), (u'281', [8796]), (u'286', [8995]), (u'293', [9163]), (u'294', [9277]), (u'3', [79]), (u'35', [961]), (u'43', [1234, 1226]), (u'49', [1381]), (u'55', [1540]), (u'62', [1791]), (u'67', [1923]), (u'69', [1974]), (u'74', [2091])]
